# %% [markdown]
# <a href="https://colab.research.google.com/github/suryakokkiligadda2003/Python-mini-projects/blob/main/Dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1 =[]
a2 =[]
a3 =[]
a4 =[]
a5 =[]

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
df = {
      'grade' :a1,
      'weight' :a2,
      'friends' :a3,
      'cousins' :a4,
      'projects' :a5
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(df) # Change 'Dataframe' to 'DataFrame'

# %%
df
# Out:
#      grade  weight  friends  cousins  projects
# 0       86      70       18        6        28
# 1       67      64       19        6        68
# 2       97      66       20        9        47
# 3        5      66       16       10        22
# 4       53      54       20        8        77
# ..     ...     ...      ...      ...       ...
# 995     85      59       11        6        41
# 996     82      70       18        5        75
# 997     41      61       11        7        33
# 998      3      54       17        5        76
# 999     23      50       16       10        33
#
# [1000 rows x 5 columns]

# %%
grade98 = df['grade']>98

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      grade  weight  friends  cousins  projects
# 0       86      70       18        6        28
# 1       67      64       19        6        68
# 2       97      66       20        9        47
# 3        5      66       16       10        22
# 4       53      54       20        8        77
# ..     ...     ...      ...      ...       ...
# 995     85      59       11        6        41
# 996     82      70       18        5        75
# 997     41      61       11        7        33
# 998      3      54       17        5        76
# 999     23      50       16       10        33
#
# [1000 rows x 5 columns]>

# %%
df.count()
# Out:
# grade       1000
# weight      1000
# friends     1000
# cousins     1000
# projects    1000
# dtype: int64

# %%
pip install matplotlib

# %%
# %matplotlib inline

# %%
friend15 = df['friends'] > 15  # Create a boolean mask for friends greater than 15
grade75 = df['grade'] > 75    # Assuming you want grades greater than 75
df[friend15 & grade75].plot() # Now, friend15 and grade75 are defined
# Out:
# <Axes: >

# %%
df[friend15 & grade75].plot(x= 'grade',y= 'projects',kind='pie')
# Out:
# <Axes: ylabel='projects'>

# %%
df[friend15 & grade75].plot(x= 'grade',y= 'projects',kind='bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df[friend15 & grade75].plot(x= 'grade',y= 'projects',kind='box')
# Out:
# <Axes: >

# %%
df[friend15 & grade75].plot(x= 'grade',y= 'projects',kind='scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
df[friend15 & grade75].plot(x= 'grade',y= 'projects',kind='area',title ='Sample Graph')
# Out:
# <Axes: title={'center': 'Sample Graph'}, xlabel='grade'>
